# %% [markdown]
# # Array

# %%
# Question 
'''
Store apple's stock proce for 5 days and answer
1. What was the price on day 1 ?
2. What was the price on day 3 ?'''

stockprice = [298,305,320,301,292]
stockprice[0]

# time = O(1)
# Out:
# 298

# %% [markdown]
# ![Screenshot_20221228_142142.png](attachment:Screenshot_20221228_142142.png)

# %% [markdown]
# ![Screenshot_20221228_143136.png](attachment:Screenshot_20221228_143136.png)

# %% [markdown]
# ![Screenshot_20221228_143444.png](attachment:Screenshot_20221228_143444.png)

# %% [markdown]
# ### in python , list is implemented as dynamic array
